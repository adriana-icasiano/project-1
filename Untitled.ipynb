# %%
import requests
import pandas as pd

# %%
response=requests.get("https://gbfs.bird.co/dc").json()

# %%
response
# Out:
# {'data': {'bikes': [{'bike_id': 'f74c3575-0ae5-4749-9a0a-c019f580e1dc',
#     'lat': 38.90133,
#     'lon': -77.042395,
#     'battery_level': 43,
#     'vehicle_type': 'scooter',
#     'is_reserved': False,
#     'is_disabled': False},
#    {'bike_id': 'c942221f-727d-46e7-8bde-35ba34a9f839',
#     'lat': 38.942745,
#     'lon': -77.025873,
#     'battery_level': 64,
#     'vehicle_type': 'scooter',
#     'is_reserved': False,
#     'is_disabled': False},
#    {'bike_id': 'a2d4bb0e-b0ca-4c5c-b753-3338931b5ef9',
#     'lat': 38.881387,
#     'lon': -77.026937,
#     'battery_level': 94,
#     'vehicle_type': 'scooter',
#     'is_reserved': True,
#     'is_disabled': False},
#    {'bike_id': '0a3824cd-68df-4123-80f0-541cfd22c115',
#     'lat': 38.88742,
#     'lon': -77.029351,
#     'battery_level': 81,
#     'vehicle_type': 'scooter',
#     'is_reserved': False,
#     'is_disabled': False},
#    {'bike_id': 'be3a1d9a-36df-4fb8-aa29-4a890b299de2',
#     'lat': 38.923686,
# ...

# %%
bike_data=response["data"]["bikes"]

# %%
bike_data
# Out:
# [{'bike_id': 'f74c3575-0ae5-4749-9a0a-c019f580e1dc',
#   'lat': 38.90133,
#   'lon': -77.042395,
#   'battery_level': 43,
#   'vehicle_type': 'scooter',
#   'is_reserved': False,
#   'is_disabled': False},
#  {'bike_id': 'c942221f-727d-46e7-8bde-35ba34a9f839',
#   'lat': 38.942745,
#   'lon': -77.025873,
#   'battery_level': 64,
#   'vehicle_type': 'scooter',
#   'is_reserved': False,
#   'is_disabled': False},
#  {'bike_id': 'a2d4bb0e-b0ca-4c5c-b753-3338931b5ef9',
#   'lat': 38.881387,
#   'lon': -77.026937,
#   'battery_level': 94,
#   'vehicle_type': 'scooter',
#   'is_reserved': True,
#   'is_disabled': False},
#  {'bike_id': '0a3824cd-68df-4123-80f0-541cfd22c115',
#   'lat': 38.88742,
#   'lon': -77.029351,
#   'battery_level': 81,
#   'vehicle_type': 'scooter',
#   'is_reserved': False,
#   'is_disabled': False},
#  {'bike_id': 'be3a1d9a-36df-4fb8-aa29-4a890b299de2',
#   'lat': 38.923686,
#   'lon': -77.031655,
#   'battery_level': 44,
#   'vehicle_type': 'scooter',
# ...

# %%
pd.DataFrame(bike_data)
# Out:
#                                   bike_id        lat        lon  \
# 0    f74c3575-0ae5-4749-9a0a-c019f580e1dc  38.901330 -77.042395
# 1    c942221f-727d-46e7-8bde-35ba34a9f839  38.942745 -77.025873
# 2    a2d4bb0e-b0ca-4c5c-b753-3338931b5ef9  38.881387 -77.026937
# 3    0a3824cd-68df-4123-80f0-541cfd22c115  38.887420 -77.029351
# 4    be3a1d9a-36df-4fb8-aa29-4a890b299de2  38.923686 -77.031655
# ..                                    ...        ...        ...
# 719  70998832-ab63-4bad-bc22-d96753a61672  38.923589 -77.050431
# 720  d000b09e-cb32-4b52-97d8-db8e0b8ee470  38.927411 -77.071897
# 721  f84e149f-cfe0-4767-aa05-1d6b0667e819  38.886600 -77.057809
# 722  5929dc51-097a-4363-a4b0-6b2095c2dad2  38.932116 -76.977959
# 723  e175bfe3-625a-4c45-bee5-04dcf0e3f219  38.884903 -77.034737
#
#      battery_level vehicle_type  is_reserved  is_disabled
# 0               43      scooter        False        False
# 1               64      scooter        False        False
# ...
