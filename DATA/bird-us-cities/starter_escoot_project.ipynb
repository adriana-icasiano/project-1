# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
# Import API key
import gmaps
# Google developer API key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
#data provided by emily and harlan https://github.com/NABSA/gbfs/blob/master/systems.csv
bigdata_df=pd.read_csv("big_data.csv")
bigdata_df.head()
# Out:
#   Country Code               Name               Location         System ID  \
# 0           AE     ADCB Bikeshare          Abu Dhabi, AE               ABU
# 1           AE        Careem BIKE              Dubai, AE       careem_bike
# 2           AR            Ecobici       Buenos Aires, AR  bike_buenosaires
# 3           AR       MiBiciTuBici  Rosario, Santa Fe, AR        biketobike
# 4           AR  Movo Buenos Aires       Buenos Aires, AR          movo_bue
#
#                                          URL  \
# 0                  https://www.bikeshare.ae/
# 1  https://www.careem.com/en-ae/careem-bike/
# 2     https://www.buenosaires.gob.ar/ecobici
# 3           https://www.mibicitubici.gob.ar/
# 4                         https://movo.me/ar
#
#                                   Auto-Discovery URL
# 0       https://api-core.bikeshare.ae/gbfs/gbfs.json
# 1    https://dubai.publicbikesystem.net/ube/gbfs/v1/
# 2  https://buenosaires.publicbikesystem.net/ube/g...
# 3  https://www.mibicitubici.gob.ar/opendata/gbfs....
# 4      https://gbfs.movo.me/v1/buenosaires/gbfs.json

# %%
#getting data from only US cities
us_data=bigdata_df.loc[(bigdata_df["Country Code"]=="US")]
us_data
# Out:
#     Country Code                Name                    Location  \
# 331           US      Austin B-cycle                  Austin, TX
# 332           US     Aventura BCycle                Aventura, FL
# 333           US          Bay Wheels  San Francisco Bay Area, CA
# 334           US    Bike Chattanooga             Chattanooga, TN
# 335           US             BikeLNK                 Lincoln, NE
# ..           ...                 ...                         ...
# 530           US        Wheels Miami                   Miami, FL
# 531           US      Wheels Orlando                 Orlando, FL
# 532           US    Wheels San Diego               San Diego, CA
# 533           US  Wheels Tallahassee             Tallahassee, FL
# 534           US        Wheels Tempe                   Tempe, AZ
#
#                                 System ID                              URL  \
# 331                         bcycle_austin          http://austinbcycle.com
# 332                       bcycle_aventura      https://aventura.bcycle.com
# 333                                    BA       https://www.baywheels.com/
# 334                      bike_chattanooga  http://www.bikechattanooga.com/
# 335                        bcycle_bikelnk       https://bikelnk.bcycle.com
# ..                                    ...                              ...
# 530  9f74fa80-fb2f-48dc-b2d8-01a889ac008a          https://takewheels.com/
# 531  9f74fa80-fb2f-48dc-b2d8-01a889ac008a          https://takewheels.com/
# 532  9f74fa80-fb2f-48dc-b2d8-01a889ac008a          https://takewheels.com/
# 533  9f74fa80-fb2f-48dc-b2d8-01a889ac008a          https://takewheels.com/
# 534  9f74fa80-fb2f-48dc-b2d8-01a889ac008a          https://takewheels.com/
#
#                                     Auto-Discovery URL
# 331    https://gbfs.bcycle.com/bcycle_austin/gbfs.json
# 332  https://gbfs.bcycle.com/bcycle_aventura/gbfs.json
# 333          https://gbfs.baywheels.com/gbfs/gbfs.json
# 334     https://chat.publicbikesystem.net/ube/gbfs/v1/
# 335   https://gbfs.bcycle.com/bcycle_bikelnk/gbfs.json
# ..                                                 ...
# 530        https://mia-gbfs.getwheelsapp.com/gbfs.json
# 531    https://orlando-gbfs.getwheelsapp.com/gbfs.json
# 532   https://sandiego-gbfs.getwheelsapp.com/gbfs.json
# 533  https://tallahassee-gbfs.getwheelsapp.com/gbfs...
# 534      https://tempe-gbfs.getwheelsapp.com/gbfs.json
#
# [204 rows x 6 columns]

# %%
#getting data for bird and lime escooter
data_scoot = us_data.loc[us_data['System ID'].str.contains("bird", case=False)]
len(data_scoot)
#data_scoot
data_scoot
# Out:
#     Country Code                Name           Location           System ID  \
# 339           US     Bird Alexandria     Alexandria, VA     bird-alexandria
# 340           US        Bird Chicago        Chicago, IL        bird-chicago
# 341           US      Bird Cleveland      Cleveland, OH      bird-cleveland
# 342           US       Bird Columbus       Columbus, OH       bird-columbus
# 343           US    Bird Culver City    Culver City, CA    bird-culver-city
# 344           US        Bird Detriot        Detroit, MI        bird-detroit
# 345           US        Bird Fairfax        Fairfax, VA        bird-fairfax
# 346           US   Bird Indianapolis    Indianapolis,IN   bird-indianapolis
# 347           US    Bird Kansas City    Kansas City, MO    bird-kansas-city
# 348           US    Bird Los Angeles    Los Angeles, CA    bird-los-angeles
# 349           US     Bird Louisville     Louisville, KY     bird-louisville
# 350           US       Bird Portland       Portland, OR       bird-portland
# 351           US  Bird San Francisco  San Francisco, CA  bird-san-francisco
# 352           US          Bird Tempe          Tempe, AZ          bird-tempe
# 353           US  Bird Washington DC     Washington, DC  bird-washington-dc
#
#                      URL                                Auto-Discovery URL
# 339  https://www.bird.co     https://mds.bird.co/gbfs/alexandria/gbfs.json
# 340  https://www.bird.co        https://mds.bird.co/gbfs/chicago/gbfs.json
# 341  https://www.bird.co      https://mds.bird.co/gbfs/cleveland/gbfs.json
# 342  https://www.bird.co       https://mds.bird.co/gbfs/columbus/gbfs.json
# 343  https://www.bird.co    https://mds.bird.co/gbfs/culver-city/gbfs.json
# 344  https://www.bird.co        https://mds.bird.co/gbfs/detroit/gbfs.json
# 345  https://www.bird.co        https://mds.bird.co/gbfs/fairfax/gbfs.json
# 346  https://www.bird.co   https://mds.bird.co/gbfs/indianapolis/gbfs.json
# 347  https://www.bird.co    https://mds.bird.co/gbfs/kansas-city/gbfs.json
# 348  https://www.bird.co    https://mds.bird.co/gbfs/los-angeles/gbfs.json
# 349  https://www.bird.co     https://mds.bird.co/gbfs/louisville/gbfs.json
# 350  https://www.bird.co       https://mds.bird.co/gbfs/portland/gbfs.json
# 351  https://www.bird.co  https://mds.bird.co/gbfs/san-francisco/gbfs.json
# 352  https://www.bird.co          https://mds.bird.co/gbfs/tempe/gbfs.json
# 353  https://www.bird.co  https://mds.bird.co/gbfs/washington-dc/gbfs.json

# %%
#getting latitudes and longitudes for city as well as coordinates of bird scooters in each cities
coord_length=[]
lat_list=[]
lon_list=[]
cities=[]
all_url=data_scoot["Auto-Discovery URL"]
type(all_url)

for url in all_url:
    
    base_url=url
    print(base_url)
    data = requests.get(base_url).json()
    #print(data)
    target_url=data["data"]["en"]["feeds"][3]["url"]
    #target_url
    data_coord=requests.get(target_url).json()
    #print(data_coord)
    coordinates=data_coord["data"]["geofencing_zones"][0]["zone_area"]["coordinates"]
    #print(coordinates)
    coord = str(coordinates)[1:-6]
    length=len(coord)
    coord_length.append(length)
    
    Lat=data_coord["data"]["geofencing_zones"][0]["lat"]
    #print(Lat)
    Lon=data_coord["data"]["geofencing_zones"][0]["lon"]
    
    #print(Lon)
    lat_list.append(Lat)
    lon_list.append(Lon)
    #city fromatting
# Out:
# https://mds.bird.co/gbfs/alexandria/gbfs.json
# https://mds.bird.co/gbfs/chicago/gbfs.json
# https://mds.bird.co/gbfs/cleveland/gbfs.json
# https://mds.bird.co/gbfs/columbus/gbfs.json
# https://mds.bird.co/gbfs/culver-city/gbfs.json
# https://mds.bird.co/gbfs/detroit/gbfs.json
# https://mds.bird.co/gbfs/fairfax/gbfs.json
# https://mds.bird.co/gbfs/indianapolis/gbfs.json
# https://mds.bird.co/gbfs/kansas-city/gbfs.json
# https://mds.bird.co/gbfs/los-angeles/gbfs.json
# https://mds.bird.co/gbfs/louisville/gbfs.json
# https://mds.bird.co/gbfs/portland/gbfs.json
# https://mds.bird.co/gbfs/san-francisco/gbfs.json
# https://mds.bird.co/gbfs/tempe/gbfs.json
# https://mds.bird.co/gbfs/washington-dc/gbfs.json

# %%
locations = list(zip(lat_list,lon_list))

# %%
#generating the heat map using the city(lat and lon values) with
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations,weights=coord_length,  
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
cities=data_scoot["Location"]
print(cities)
# Out:
# 339       Alexandria, VA
# 340          Chicago, IL
# 341        Cleveland, OH
# 342         Columbus, OH
# 343      Culver City, CA
# 344          Detroit, MI
# 345          Fairfax, VA
# 346      Indianapolis,IN
# 347      Kansas City, MO
# 348      Los Angeles, CA
# 349       Louisville, KY
# 350         Portland, OR
# 351    San Francisco, CA
# 352            Tempe, AZ
# 353       Washington, DC
# Name: Location, dtype: object

# %%
carbon_emi=pd.read_csv("carbonemission.csv")
carbon_emi
# Out:
#       Year                               CBSA CO 2nd Max 1-hr CO 2nd Max 8-hr  \
# 0     2020                       Aberdeen, SD               .               .
# 1     2020                         Adrian, MI               .               .
# 2     2020                          Akron, OH               .               .
# 3     2020                         Albany, GA               .               .
# 4     2020        Albany-Schenectady-Troy, NY               .               .
# ...    ...                                ...             ...             ...
# 2931  2015                   Worcester, MA-CT             1.4               1
# 2932  2015                   York-Hanover, PA             1.5             0.9
# 2933  2015  Youngstown-Warren-Boardman, OH-PA               .               .
# 2934  2015                      Yuba City, CA             0.8             0.5
# 2935  2015                           Yuma, AZ               .               .
#
#      NO2 98th Percentile 1-hr NO2 Mean 1-hr Ozone 2nd Max 1-hr  \
# 0                           .             .                  .
# 1                           .             .               0.07
# 2                           .             .               0.08
# 3                           .             .                  .
# 4                           .             .               0.06
# ...                       ...           ...                ...
# 2931                       55            13               0.09
# 2932                       52            10               0.09
# 2933                        .             .               0.08
# 2934                       39             7               0.08
# 2935                        .             .               0.09
#
#      Ozone 4th Max 8-hr SO2 99th Percentile 1-hr SO2 2nd Max 24-hr  \
# 0                     .                        .                 .
# 1                 0.067                        .                 .
# 2                 0.063                        4                 3
# 3                     .                        .                 .
# 4                 0.055                        2                 1
# ...                 ...                      ...               ...
# 2931               0.07                        5                 3
# 2932              0.074                       30                 7
# 2933               0.07                       32                 7
# 2934              0.072                        .                 .
# 2935              0.077                        .                 .
#
#      SO2 Mean 1-hr PM2.5 98th Percentile 24-hr PM2.5 Weighted Mean 24-hr  \
# 0                .                          15                       5.6
# 1                .                          19                       8.2
# 2                0                          20                       9.3
# 3                .                          28                      10.4
# 4                0                          23                       8.7
# ...            ...                         ...                       ...
# 2931             1                          18                       6.8
# 2932             2                          27                      10.6
# 2933             1                          26                        11
# 2934             .                          31                       9.6
# 2935             .                           .                         .
#
#      PM10 2nd Max 24-hr PM10 Mean 24-hr Lead Max 3-Mo Avg
# 0                    75              21                 .
# 1                     .               .                 .
# 2                     .               .                 .
# 3                     .               .                 .
# 4                     .               .                 .
# ...                 ...             ...               ...
# 2931                 35              15                 .
# 2932                 37              16                 .
# 2933                 41              19                 .
# 2934                 66              22                 .
# 2935                182              38                 .
#
# [2936 rows x 16 columns]

# %%
clean_df=carbon_emi.loc[(carbon_emi["CBSA"]=="Chicago-Naperville-Elgin, IL-IN-WI")|(carbon_emi["CBSA"]=="Cleveland-Elyria, OH")|(carbon_emi["CBSA"]=="Columbus, OH")|(carbon_emi["CBSA"]=="San Francisco-Oakland-Hayward, CA")|(carbon_emi["CBSA"]=="Washington-Arlington-Alexandria, DC-VA-MD-WV")|(carbon_emi["CBSA"]=="Los Angeles-Long Beach-Anaheim, CA")|(carbon_emi["CBSA"]=="Detroit-Warren-Dearborn, MI")|(carbon_emi["CBSA"]=="Portland-Vancouver-Hillsboro, OR-WA")]
clean_df
# Out:
#       Year                                          CBSA CO 2nd Max 1-hr  \
# 79    2020            Chicago-Naperville-Elgin, IL-IN-WI             1.7
# 87    2020                          Cleveland-Elyria, OH             5.4
# 94    2020                                  Columbus, OH             1.8
# 113   2020                   Detroit-Warren-Dearborn, MI             2.4
# 248   2020            Los Angeles-Long Beach-Anaheim, CA             3.7
# 337   2020           Portland-Vancouver-Hillsboro, OR-WA            15.1
# 383   2020             San Francisco-Oakland-Hayward, CA             3.5
# 455   2020  Washington-Arlington-Alexandria, DC-VA-MD-WV             2.2
# 558   2019            Chicago-Naperville-Elgin, IL-IN-WI             3.9
# 566   2019                          Cleveland-Elyria, OH             4.4
# 574   2019                                  Columbus, OH             1.6
# 593   2019                   Detroit-Warren-Dearborn, MI             4.7
# 731   2019            Los Angeles-Long Beach-Anaheim, CA             3.8
# 822   2019           Portland-Vancouver-Hillsboro, OR-WA             1.8
# 868   2019             San Francisco-Oakland-Hayward, CA             5.6
# 943   2019  Washington-Arlington-Alexandria, DC-VA-MD-WV             2.1
# 1047  2018            Chicago-Naperville-Elgin, IL-IN-WI             3.4
# 1055  2018                          Cleveland-Elyria, OH             4.7
# 1062  2018                                  Columbus, OH             1.7
# 1083  2018                   Detroit-Warren-Dearborn, MI             3.1
# 1226  2018            Los Angeles-Long Beach-Anaheim, CA             4.4
# 1316  2018           Portland-Vancouver-Hillsboro, OR-WA             1.9
# 1362  2018             San Francisco-Oakland-Hayward, CA             3.6
# 1441  2018  Washington-Arlington-Alexandria, DC-VA-MD-WV             2.1
# 1544  2017            Chicago-Naperville-Elgin, IL-IN-WI             3.5
# 1552  2017                          Cleveland-Elyria, OH             5.4
# 1560  2017                                  Columbus, OH             1.9
# 1580  2017                   Detroit-Warren-Dearborn, MI             8.2
# 1720  2017            Los Angeles-Long Beach-Anaheim, CA             5.6
# 1811  2017           Portland-Vancouver-Hillsboro, OR-WA             1.6
# 1858  2017             San Francisco-Oakland-Hayward, CA             3.1
# 1938  2017  Washington-Arlington-Alexandria, DC-VA-MD-WV             2.7
# 2042  2016            Chicago-Naperville-Elgin, IL-IN-WI             2.3
# 2050  2016                          Cleveland-Elyria, OH             5.8
# 2057  2016                                  Columbus, OH             2.5
# 2077  2016                   Detroit-Warren-Dearborn, MI             2.5
# 2214  2016            Los Angeles-Long Beach-Anaheim, CA             4.3
# 2299  2016           Portland-Vancouver-Hillsboro, OR-WA             1.7
# 2347  2016             San Francisco-Oakland-Hayward, CA             2.5
# 2424  2016  Washington-Arlington-Alexandria, DC-VA-MD-WV             3.7
# 2528  2015            Chicago-Naperville-Elgin, IL-IN-WI             4.5
# 2536  2015                          Cleveland-Elyria, OH             5.8
# 2544  2015                                  Columbus, OH             2.1
# 2562  2015                   Detroit-Warren-Dearborn, MI             2.4
# 2705  2015            Los Angeles-Long Beach-Anaheim, CA             4.3
# 2791  2015           Portland-Vancouver-Hillsboro, OR-WA             2.4
# 2839  2015             San Francisco-Oakland-Hayward, CA             3.8
# 2914  2015  Washington-Arlington-Alexandria, DC-VA-MD-WV             5.1
#
#      CO 2nd Max 8-hr NO2 98th Percentile 1-hr NO2 Mean 1-hr  \
# 79               1.1                       50            16
# 87               2.2                       36             8
# 94               1.3                       39             8
# 113              1.8                       44            13
# 248              2.8                       86            23
# 337             14.1                       30            10
# 383              2.1                       48            14
# 455              1.8                       45            14
# 558              1.6                       56            17
# 566              2.3                       45            10
# 574                1                       42            10
# 593                2                       50            16
# 731              2.9                       78            23
# 822              1.4                       33            11
# 868              1.7                       48            15
# 943              1.6                       49            16
# 1047             1.6                       61            18
# 1055             3.1                       49            11
# 1062             1.2                       44            10
# 1083             2.4                       43            16
# 1226             3.1                       79            22
# 1316             1.6                       38            12
# 1362               3                       59            17
# 1441             1.9                       49            15
# 1544             1.4                       55            16
# 1552             3.3                       46            11
# 1560             1.6                       40            11
# 1580             1.8                       47            16
# 1720             3.5                       83            25
# 1811             1.1                       40            12
# 1858             2.1                       59            17
# 1938             2.3                       58            15
# 2042             1.1                       61            17
# 2050             3.9                       50            11
# 2057             1.8                       42            12
# 2077             1.5                       50            16
# 2214             3.6                       77            24
# 2299             1.3                       35            13
# 2347               2                       51            17
# 2424             2.3                       59            18
# 2528             2.1                       62            18
# 2536             2.9                       50            13
# 2544             1.5                       48            12
# 2562             1.7                       50            18
# 2705               3                       66            25
# 2791             1.9                       36            14
# 2839               2                       53            18
# 2914               2                       53            13
#
#      Ozone 2nd Max 1-hr Ozone 4th Max 8-hr SO2 99th Percentile 1-hr  \
# 79                  0.1              0.079                       81
# 87                 0.09              0.075                       80
# 94                 0.08              0.067                        .
# 113                0.09              0.074                       76
# 248                0.17              0.124                        3
# 337                0.08               0.07                        2
# 383                 0.1              0.071                       14
# 455                0.09              0.065                        4
# 558                0.09              0.071                       79
# 566                0.08              0.071                       23
# 574                0.08              0.068                        .
# 593                0.09               0.07                       64
# 731                0.12              0.101                        8
# 822                0.08              0.065                        3
# 868                 0.1              0.072                       15
# 943                0.09              0.075                        5
# 1047                0.1              0.084                       28
# 1055               0.09              0.076                       53
# 1062               0.08              0.067                        .
# 1083               0.09              0.077                       82
# 1226               0.13              0.102                        9
# 1316               0.09               0.07                        3
# 1362                0.1              0.069                       20
# 1441               0.11              0.073                        5
# 1544                0.1              0.079                       36
# 1552               0.09              0.073                       41
# 1560               0.08               0.07                        3
# 1580               0.09              0.076                       70
# 1720               0.15              0.111                       14
# 1811                0.1              0.083                        3
# 1858               0.13              0.079                       16
# 1938               0.09              0.072                        4
# 2042                0.1               0.08                       31
# 2050               0.09              0.077                      370
# 2057               0.09              0.072                        4
# 2077               0.09              0.075                       59
# 2214               0.14                0.1                       12
# 2299               0.08              0.064                        3
# 2347               0.11              0.082                       13
# 2424               0.09              0.076                        8
# 2528               0.09              0.075                       39
# 2536               0.08              0.074                       89
# 2544               0.08              0.071                        6
# 2562               0.09              0.075                       76
# 2705               0.13                0.1                        7
# 2791               0.09              0.069                        4
# 2839                0.1              0.074                       12
# 2914                0.1              0.073                       13
#
#      SO2 2nd Max 24-hr SO2 Mean 1-hr PM2.5 98th Percentile 24-hr  \
# 79                  15             2                          33
# 87                  14             1                          23
# 94                   .             0                          18
# 113                 17             2                          26
# 248                  1             0                          53
# 337                  1             0                         208
# 383                  4             2                          66
# 455                  3             1                          27
# 558                 13             2                          28
# 566                  7             2                          27
# 574                  .             0                          25
# 593                 16             3                          31
# 731                  2             0                          30
# 822                  1             0                          25
# 868                  4             1                          19
# 943                  3             1                          32
# 1047                 8             2                          27
# 1055                11             1                          28
# 1062                 .             0                          24
# 1083                26             2                          29
# 1226                 2             1                          42
# 1316                 1             0                          32
# 1362                 4             1                          82
# 1441                 3             1                          23
# 1544                11             2                          24
# 1552                14             1                          27
# 1560                 1             0                          22
# 1580                29             3                          30
# 1720                 3             1                          53
# 1811                 2             0                          36
# 1858                 5             2                          43
# 1938                 3             1                          21
# 2042                11             2                          21
# 2050               145             2                          22
# 2057                 2             0                          18
# 2077                17             3                          26
# 2214                 4             1                          39
# 2299                 1             0                          18
# 2347                 5             2                          19
# 2424                 4             1                          21
# 2528                11             2                         106
# 2536                31             3                          27
# 2544                 2             0                          24
# 2562                21             2                          32
# 2705                 2             0                          42
# 2791                 2             0                          34
# 2839                 4             2                          31
# 2914                 5             1                          28
#
#      PM2.5 Weighted Mean 24-hr PM10 2nd Max 24-hr PM10 Mean 24-hr  \
# 79                        10.8                149              37
# 87                         9.8                 66              20
# 94                         7.4                  .               .
# 113                       10.6                 50              24
# 248                       15.9                169              29
# 337                       14.2                 35              11
# 383                       11.8                 58              22
# 455                        7.9                 46              15
# 558                       10.8                 69              19
# 566                       10.9                 79              31
# 574                        9.9                 39              17
# 593                       12.6                 89              25
# 731                       13.4                159              29
# 822                          7                 29              11
# 868                        9.4                 53              15
# 943                        9.1                 46              17
# 1047                      11.2                 76              23
# 1055                      11.1                 74              30
# 1062                       9.1                  .               .
# 1083                      11.9                123              29
# 1226                      13.4                 90              33
# 1316                       8.1                 27              12
# 1362                      14.4                102              21
# 1441                       9.5                 40              16
# 1544                      10.3                 82              22
# 1552                      11.2                 67              30
# 1560                       8.8                 52              22
# 1580                      11.2                133              26
# 1720                      14.9                111              33
# 1811                       8.2                 62              15
# 1858                      12.8                 59              21
# 1938                      10.2                 44              16
# 2042                       9.9                131              27
# 2050                      10.7                 86              37
# 2057                       8.7                 52              20
# 2077                      11.3                181              28
# 2214                      14.7                127              34
# 2299                       5.9                 32              10
# 2347                       8.7                 29              16
# 2424                       8.6                 41              17
# 2528                      13.1                126              23
# 2536                      13.3                 86              42
# 2544                      10.9                  .               .
# 2562                      11.7                139              29
# 2705                      12.6                 95              37
# 2791                         8                 45              16
# 2839                      10.2                 38              18
# 2914                      11.2                 42              17
#
#      Lead Max 3-Mo Avg
# 79                0.01
# 87                   .
# 94                   .
# 113               0.04
# 248               0.02
# 337                  .
# 383                  .
# 455                  .
# 558               0.01
# 566               0.01
# 574                  .
# 593               0.03
# 731               0.02
# 822                  .
# 868                  .
# 943                  .
# 1047              0.01
# 1055              0.06
# 1062              0.01
# 1083              0.08
# 1226              0.06
# 1316                 .
# 1362                 .
# 1441                 .
# 1544              0.02
# 1552              0.03
# 1560              0.01
# 1580              0.08
# 1720              0.01
# 1811                 .
# 1858                 .
# 1938                 .
# 2042              0.05
# 2050              0.03
# 2057              0.01
# 2077              0.07
# 2214              0.03
# 2299                 .
# 2347              0.03
# 2424              0.01
# 2528              0.42
# 2536              0.03
# 2544              0.01
# 2562              0.05
# 2705              0.04
# 2791                 .
# 2839                 .
# 2914                 0

# %%
#loopin through cities and findin the realtion between years and carbon emission
col_choice = ["Chicago-Naperville-Elgin, IL-IN-WI","Cleveland-Elyria, OH","Columbus, OH","San Francisco-Oakland-Hayward, CA","Washington-Arlington-Alexandria, DC-VA-MD-WV","Los Angeles-Long Beach-Anaheim, CA","Detroit-Warren-Dearborn, MI","Portland-Vancouver-Hillsboro, OR-WA"]

for pos, col in enumerate(col_choice):  
    #Pick a first col
    print(col)
    x_axis= carbon_emi.loc[(carbon_emi["CBSA"]==col_choice[pos]),"CO 2nd Max 1-hr"]
    print(x_axis)
    y_axis=carbon_emi.loc[(carbon_emi["CBSA"]==col_choice[pos]),"Year"]
    f=plt.scatter(x_axis,y_axis,marker="o",facecolors="blue",edgecolors="black")
    plt.title(f"Plot of year vs CO Emission for city {col_choice[pos]}")
    plt.xlabel(f"Carbon Monoxide(ppm)")
    plt.ylabel(f"Year")
    plt.grid()
    plt.tight_layout()
    plt.savefig(f"YearvsCo{pos}.png")
    plt.show()
# Out:
# Chicago-Naperville-Elgin, IL-IN-WI
# 79      1.7
# 558     3.9
# 1047    3.4
# 1544    3.5
# 2042    2.3
# 2528    4.5
# Name: CO 2nd Max 1-hr, dtype: object
# Cleveland-Elyria, OH
# 87      5.4
# 566     4.4
# 1055    4.7
# 1552    5.4
# 2050    5.8
# 2536    5.8
# Name: CO 2nd Max 1-hr, dtype: object
# Columbus, OH
# 94      1.8
# 574     1.6
# 1062    1.7
# 1560    1.9
# 2057    2.5
# 2544    2.1
# Name: CO 2nd Max 1-hr, dtype: object
# San Francisco-Oakland-Hayward, CA
# 383     3.5
# 868     5.6
# 1362    3.6
# 1858    3.1
# 2347    2.5
# 2839    3.8
# Name: CO 2nd Max 1-hr, dtype: object
# Washington-Arlington-Alexandria, DC-VA-MD-WV
# 455     2.2
# 943     2.1
# 1441    2.1
# 1938    2.7
# 2424    3.7
# 2914    5.1
# Name: CO 2nd Max 1-hr, dtype: object
# Los Angeles-Long Beach-Anaheim, CA
# 248     3.7
# 731     3.8
# 1226    4.4
# 1720    5.6
# 2214    4.3
# 2705    4.3
# Name: CO 2nd Max 1-hr, dtype: object
# Detroit-Warren-Dearborn, MI
# 113     2.4
# 593     4.7
# 1083    3.1
# 1580    8.2
# 2077    2.5
# 2562    2.4
# Name: CO 2nd Max 1-hr, dtype: object
# Portland-Vancouver-Hillsboro, OR-WA
# 337     15.1
# 822      1.8
# 1316     1.9
# 1811     1.6
# 2299     1.7
# 2791     2.4
# Name: CO 2nd Max 1-hr, dtype: object

# %%
col_choice = ["Chicago-Naperville-Elgin, IL-IN-WI","Cleveland-Elyria, OH","Columbus, OH","San Francisco-Oakland-Hayward, CA","Washington-Arlington-Alexandria, DC-VA-MD-WV","Los Angeles-Long Beach-Anaheim, CA","Detroit-Warren-Dearborn, MI","Portland-Vancouver-Hillsboro, OR-WA"]

for pos, col in enumerate(col_choice):  
    #Pick a first col
    print(col)
    x_axis= carbon_emi.loc[(carbon_emi["CBSA"]==col_choice[pos]),"NO2 Mean 1-hr"]
    y_axis=carbon_emi.loc[(carbon_emi["CBSA"]==col_choice[pos]),"Year"]
    f=plt.scatter(x_axis,y_axis,marker="o",facecolors="blue",edgecolors="black")
    plt.title(f"Plot of Year vs {col_choice[pos]}")
    plt.xlabel(f"NO2 Mean 1-hr")
    plt.ylabel(f"Year")
    plt.grid()
    plt.tight_layout()
    plt.savefig(f"YearvsNO{pos}.png")
    plt.show()
# Out:
# Chicago-Naperville-Elgin, IL-IN-WI
# Cleveland-Elyria, OH
# Columbus, OH
# San Francisco-Oakland-Hayward, CA
# Washington-Arlington-Alexandria, DC-VA-MD-WV
# Los Angeles-Long Beach-Anaheim, CA
# Detroit-Warren-Dearborn, MI
# Portland-Vancouver-Hillsboro, OR-WA
