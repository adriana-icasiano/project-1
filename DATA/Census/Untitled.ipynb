# %%
import pandas as pd
from county import counties, states, duplicates

# %%
file = 'acs2017_county_data.csv'

df = pd.read_csv(file)
df = df.loc[df["State"].isin(states), :]

df.head()
# Out:
#      CountyId     State           County  TotalPop     Men   Women  Hispanic  \
# 111      5001  Arkansas  Arkansas County     18352    8785    9567       3.0
# 112      5003  Arkansas    Ashley County     20771   10126   10645       5.2
# 113      5005  Arkansas    Baxter County     41093   19857   21236       2.1
# 114      5007  Arkansas    Benton County    251823  124632  127191      16.3
# 115      5009  Arkansas     Boone County     37212   18198   19014       2.3
#
#      White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 111   70.2   26.0     0.0  ...   3.1          1.5         3.1         14.6
# 112   68.0   25.6     0.2  ...   2.3          3.0         1.6         20.4
# 113   95.1    0.2     0.5  ...   2.4          0.7         3.3         16.4
# 114   74.2    1.6     1.4  ...   1.6          0.8         3.7         19.9
# 115   94.2    0.4     1.1  ...   1.0          1.3         3.8         19.4
#
#      Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 111      7920         75.7        15.5           8.0         0.9           8.5
# 112      7905         78.8        18.1           2.7         0.4           9.9
# 113     15926         79.5        11.7           8.6         0.2           5.8
# 114    119813         86.0         8.2           5.7         0.1           3.1
# 115     15773         78.4        13.1           8.2         0.3           6.1
#
# [5 rows x 37 columns]

# %%
lime_df = df.loc[df["County"].isin(counties), :]
lime_df
# Out:
#       CountyId      State            County  TotalPop     Men   Women  \
# 115       5009   Arkansas      Boone County     37212   18198   19014
# 130       5039   Arkansas     Dallas County      7585    3639    3946
# 134       5047   Arkansas   Franklin County     17803    8674    9129
# 145       5069   Arkansas  Jefferson County     71373   35154   36219
# 155       5089   Arkansas     Marion County     16374    8050    8324
# ...        ...        ...               ...       ...     ...     ...
# 3062     55031  Wisconsin    Douglas County     43503   21734   21769
# 3074     55055  Wisconsin  Jefferson County     84586   42282   42304
# 3087     55079  Wisconsin  Milwaukee County    956586  462784  493802
# 3088     55081  Wisconsin     Monroe County     45303   22893   22410
# 3094     55093  Wisconsin     Pierce County     41226   20501   20725
#
#       Hispanic  White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  \
# 115        2.3   94.2    0.4     1.1  ...   1.0          1.3         3.8
# 130        3.1   53.2   40.0     0.4  ...   5.6          2.2         1.9
# 134        2.9   92.4    1.0     1.6  ...   2.4          0.6         5.1
# 145        2.0   39.6   56.3     0.2  ...   1.7          2.4         2.1
# 155        2.2   94.7    0.2     1.0  ...   1.8          0.1         4.5
# ...        ...    ...    ...     ...  ...   ...          ...         ...
# 3062       1.5   91.9    1.2     1.7  ...   3.5          1.6         3.9
# 3074       7.0   89.9    0.8     0.1  ...   3.3          1.0         4.2
# 3087      14.6   52.2   26.1     0.5  ...   3.6          1.6         3.4
# 3088       4.2   91.2    1.5     0.9  ...   3.2          1.9         4.6
# 3094       1.9   94.6    0.6     0.2  ...   4.7          1.1         4.8
#
#       MeanCommute  Employed  PrivateWork  PublicWork  SelfEmployed  \
# 115          19.4     15773         78.4        13.1           8.2
# 130          27.5      2910         72.2        23.7           3.8
# 134          26.8      6598         74.1        20.0           5.6
# 145          20.9     26874         70.0        25.7           4.1
# 155          22.1      5353         73.7        14.7          11.6
# ...           ...       ...          ...         ...           ...
# 3062         22.3     21594         82.3        13.4           4.2
# 3074         23.8     44955         83.6        11.3           5.0
# 3087         22.4    454524         84.7        11.6           3.6
# 3088         19.8     21433         72.4        20.3           7.0
# 3094         25.9     23358         79.5        14.2           5.9
#
#       FamilyWork  Unemployment
# 115          0.3           6.1
# 130          0.3           6.4
# 134          0.3           6.6
# 145          0.2          10.0
# 155          0.0           7.7
# ...          ...           ...
# 3062         0.2           5.6
# 3074         0.1           4.3
# 3087         0.1           7.1
# 3088         0.3           4.7
# 3094         0.4           2.7
#
# [173 rows x 37 columns]

# %%
len(counties)
# Out:
# 59

# %%
lime_df['County'].value_counts()
# Out:
# Jefferson County        18
# Franklin County         16
# Monroe County           12
# Wayne County            12
# Marion County           11
# Douglas County           9
# Hamilton County          8
# Orange County            7
# Pulaski County           7
# Fayette County           7
# Boone County             6
# Pierce County            4
# Butler County            4
# Cook County              3
# Dallas County            3
# St. Louis County         2
# Mecklenburg County       2
# Davidson County          2
# Kings County             2
# King County              2
# Ramsey County            1
# Wake County              1
# Alameda County           1
# Queens County            1
# Olmsted County           1
# Oklahoma County          1
# Travis County            1
# Denver County            1
# Lucas County             1
# Ada County               1
# Suffolk County           1
# Durham County            1
# Guilford County          1
# Nueces County            1
# New York County          1
# Milwaukee County         1
# Norfolk city             1
# Sacramento County        1
# Spokane County           1
# Miami-Dade County        1
# Cuyahoga County          1
# Placer County            1
# Bulloch County           1
# Multnomah County         1
# Santa Clara County       1
# Hennepin County          1
# Santa Barbara County     1
# Baltimore County         1
# Utah County              1
# Lubbock County           1
# District of Columbia     1
# Ingham County            1
# Tulsa County             1
# Hillsborough County      1
# Weber County             1
# San Francisco County     1
# Name: County, dtype: int64

# %%
lime_df.columns.tolist()

clean_df = pd.DataFrame(columns=lime_df.columns.tolist())
clean_df
# Out:
# Empty DataFrame
# Columns: [CountyId, State, County, TotalPop, Men, Women, Hispanic, White, Black, Native, Asian, Pacific, VotingAgeCitizen, Income, IncomeErr, IncomePerCap, IncomePerCapErr, Poverty, ChildPoverty, Professional, Service, Office, Construction, Production, Drive, Carpool, Transit, Walk, OtherTransp, WorkAtHome, MeanCommute, Employed, PrivateWork, PublicWork, SelfEmployed, FamilyWork, Unemployment]
# Index: []
#
# [0 rows x 37 columns]

# %%
count = 0
add = []

for n in duplicates:
    temp_df = df.loc[df["County"]==n[0], :]
    temp_df = df.loc[df["State"]==n[1], :]
    
    
pd.conc
# Out:
#       CountyId           State           County  TotalPop    Men  Women  \
# 993      21001        Kentucky     Adair County     19304   9632   9672
# 994      21003        Kentucky     Allen County     20628  10227  10401
# 995      21005        Kentucky  Anderson County     22017  10639  11378
# 996      21007        Kentucky   Ballard County      8152   4077   4075
# 997      21009        Kentucky    Barren County     43418  21123  22295
# ...        ...             ...              ...       ...    ...    ...
# 1985     37191  North Carolina     Wayne County    124496  61075  63421
# 1986     37193  North Carolina    Wilkes County     68525  33737  34788
# 1987     37195  North Carolina    Wilson County     81379  38532  42847
# 1988     37197  North Carolina    Yadkin County     37825  18574  19251
# 1989     37199  North Carolina    Yancey County     17605   8689   8916
#
#       Hispanic  White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  \
# 993        1.8   93.4    3.6     0.1  ...   2.6          0.5         3.4
# 994        1.9   95.4    1.9     0.0  ...   2.5          1.6         6.9
# 995        1.7   94.2    2.4     0.0  ...   0.5          0.2         2.1
# 996        1.2   93.0    3.9     0.2  ...   0.4          0.8         3.6
# 997        3.0   90.7    3.9     0.2  ...   1.7          1.0         5.1
# ...        ...    ...    ...     ...  ...   ...          ...         ...
# 1985      11.3   54.1   30.1     0.3  ...   1.6          0.8         2.1
# 1986       6.1   87.9    4.1     0.3  ...   1.0          0.4         2.8
# 1987      10.1   47.3   39.5     0.4  ...   1.3          4.3         1.7
# 1988      10.9   84.5    3.4     0.1  ...   0.5          1.2         4.6
# 1989       4.9   92.8    0.8     0.4  ...   2.8          1.2         5.1
#
#       MeanCommute  Employed  PrivateWork  PublicWork  SelfEmployed  \
# 993          22.2      7988         74.1        15.8           9.9
# 994          24.1      8443         74.8        13.9          11.3
# 995          26.6     10357         69.3        24.1           6.5
# 996          23.6      3394         81.4        11.9           6.7
# 997          20.7     18377         79.0        13.6           7.0
# ...           ...       ...          ...         ...           ...
# 1985         21.9     51308         75.5        19.3           4.9
# 1986         23.3     28169         77.0        15.1           7.8
# 1987         20.7     35115         81.7        13.6           4.6
# 1988         26.6     15725         81.0        11.6           7.2
# 1989         28.7      7013         73.5        18.3           8.1
#
#       FamilyWork  Unemployment
# 993          0.1           6.2
# 994          0.1           7.5
# 995          0.1           6.3
# 996          0.0           4.7
# 997          0.4           7.6
# ...          ...           ...
# 1985         0.3           9.7
# 1986         0.2           7.5
# 1987         0.1           8.1
# 1988         0.2           5.9
# 1989         0.1           8.3
#
# [1927 rows x 37 columns]
